# %%
# Import libraries
import abm_plot as abm
import subprocess

# %%
cell_data = abm.read_data('./Data/giant.csv','./Data/small.csv',show=True)

# %%
#abm.generate_options(n_timesteps=800,print_inter=20,scale=5)
#rc = subprocess.call("./01_first_run.sh")

# %%
abm.plot_phenotypes('./Forward_Model/cells_data*.txt',output_name='abm_data_plots_')

# %%
abm.print_abm('./Forward_Model/saida1_*.txt',output_name='abm_solution_',show=False)
# Out:
# 100%|██████████| 26/26 [04:03<00:00,  9.37s/it]

# %%
abm.save_video(output_name='abm_solution_',video_name='video')

# %%
abm.plot_data_model('./Forward_Model/cells_data*.txt',cell_data,output_name='abm_data_plots_')
