# %%
# Import libraries
import abm_plot as abm
import subprocess

# %%
cell_data = abm.read_data('./Data/giant.csv','./Data/small.csv',show=True)

# %%
#abm.generate_options(n_timesteps=800,print_inter=400)

# %%
abm.plot_phenotypes('./Forward_Model/cells_data_log*.dat',output_name='abm_data_plots_')

# %%
#abm.print_abm('./Forward_Model/saida1_*.txt',output_name='abm_solution_',show=False)

# %%
#abm.save_video(output_name='abm_solution_',video_name='video')

# %%
abm.plot_data_model('./Forward_Model/cells_data_log*.dat',cell_data,output_name='abm_data_plots_')

# %%
abm.plot_all_model('./Forward_Model/cells_data_log*.dat',output_name='abm_all_small_log')
# Out:
# with10
# with25
# with35
# with36
# without

# %%
abm.plot_long_data(cell_data,output_name='abm_data_long')
